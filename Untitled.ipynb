# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv('./testSetSeg/manifest.csv').drop(['index', 'originalFreq', 'sampleFreq', 'fileName'], axis=1)

# %%
x = df.loc[lambda df: df['patientID'] == 258, :]
x
# Out:
#        patientID  age gender sessionID fileID  segment  seizureDuration  \
# 0            258   41   male        s2     t2        1          120.500
# 1            258   41   male        s2     t2        2          120.500
# 2            258   41   male        s2     t2        3          120.500
# 3            258   41   male        s2     t2        4          120.500
# 4            258   41   male        s2     t2        5          120.500
# 5            258   41   male        s2     t2        6          120.500
# 6            258   41   male        s2     t2        7          120.500
# 7            258   41   male        s2     t2        8          120.500
# 8            258   41   male        s2     t2        9          120.500
# 9            258   41   male        s2     t2       10          120.500
# 10           258   41   male        s2     t2       11          120.500
# 11           258   41   male        s2     t2       12          120.500
# ...

# %%
# Out:
#                   patientID  age  gender  sessionID  fileID  segment  \
# sessionID fileID
# s1        t0              1    1       1          1       1       47
# s2        t2              1    1       1          1       1       24
# s3        t0              1    1       1          1       1       26
#           t1              1    1       1          1       1       23
#           t2              1    1       1          1       1       38
#           t3              1    1       1          1       1       22
#           t4              1    1       1          1       1       21
#           t5              1    1       1          1       1       20
# s4        t0              1    1       1          1       1       36
#
#                   seizureDuration  seizureType
# sessionID fileID
# s1        t0                    6            1
# s2        t2                    1            1
# s3        t0                    1            1
#           t1                    1            1
# ...
