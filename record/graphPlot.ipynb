# %%
from mne import Epochs, pick_types, find_events
from mne.io import concatenate_raws, read_raw_edf, read_raw_fif

# raw = read_raw_fif('./testDir/00000492_s003_t000raw.fif',
#                    preload=True)

# %%
x = raw.info['ch_names']
raw = raw.reorder_channels(['FP1', 'F3', 'FP2', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1',
                            'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'FZ', 'CZ', 'PZ'])
a = raw.get_data(0)
raw = raw.reorder_channels(['FP2', 'F3', 'FP1', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1',
                            'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'FZ', 'CZ', 'PZ'])
b = raw.get_data(2)
print(a==b)
print(x)
print(raw)
# Out:
# [[ True  True  True ...  True  True  True]]
# ['FP2', 'F3', 'FP1', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'FZ', 'CZ', 'PZ']
# <Raw  |  00000492_s003_t000raw.fif, n_channels x n_times : 19 x 3790 (29.6 sec), ~603 kB, data loaded>

# %%
raw.plot()

# %%
from os import walk

f = []
for (dirpath, dirnames, filenames) in walk('./testDir'):
    f.extend(filenames)
    break

for i in f:
    raw = read_raw_fif('./testDir/' + i,preload=True)
    raw.plot()
# Out:
# Opening raw data file /Users/zaynjarvis/EEG/code/testDir/492_s3_t10_raw.fif...
# Isotrak not found
#     Range : 0 ... 3611 =      0.000 ...    28.211 secs
# Ready.
# Reading 0 ... 3611  =      0.000 ...    28.211 secs...
# Opening raw data file /Users/zaynjarvis/EEG/code/testDir/492_s3_t5_raw.fif...
# Isotrak not found
#     Range : 0 ... 2678 =      0.000 ...    20.922 secs
# Ready.
# Reading 0 ... 2678  =      0.000 ...    20.922 secs...
# Opening raw data file /Users/zaynjarvis/EEG/code/testDir/883_s2_t0_raw.fif...
# Isotrak not found
#     Range : 0 ... 13040 =      0.000 ...   101.875 secs
# Ready.
# Reading 0 ... 13040  =      0.000 ...   101.875 secs...
# Opening raw data file /Users/zaynjarvis/EEG/code/testDir/492_s3_t4_raw.fif...
# Isotrak not found
#     Range : 0 ... 5212 =      0.000 ...    40.719 secs
# Ready.
# Reading 0 ... 5212  =      0.000 ...    40.719 secs...
# Opening raw data file /Users/zaynjarvis/EEG/code/testDir/492_s3_t11_raw.fif...
# Isotrak not found
# ...
